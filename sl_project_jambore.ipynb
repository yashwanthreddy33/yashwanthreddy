# %%
# Admission problem

# Jamboree admission is a service that helps students apply to universities in abroad
# for undergraduate,graduate,MBA and Phd programs.
# Jambore offers a range of services to help the students with the application process.

# The jamboree admission center analyze the chance of admit for the students who wants to study in
# different abroad universities.Jamboree analyses the chance of admit with the help of some criteria
# like(GREScore,TOFELScore,University rating,SOP,LOR,CGPA,Research)

# Following are the attributes of the dataset
# 1.SerialNo : Each number Represents the student who applied for Jambore admission.
# 2.GREScore : Graduate Record Examination is a criteria for the admission of abroad universities.
# 3.TOFELScore : Test Of English As a Foreign Langauge is a criteria for the admission of abroad universities.
# 4.UniversityRating : Rating of the university that you are applying in abroad.
# 5.SOP : A Statement of Purpose (SOP), also known as a research statement or a letter of intent, is directed to the admission panel.
# It discusses your career path, interests, professional contributions, goals, and motivations for pursuing a specific program.
# 6.LOR : A Statement of Purpose (SOP), also known as a research statement or a letter of intent, is directed to the admission panel.
# It discusses your career path, interests, professional contributions, goals, and motivations for pursuing a specific program.
# 7.CGPA : CGPA is a calculation of the average grade point obtained in all subjects except in additional subjects as per the study scheme.
# 8.Research : Research is a criteria for the jambore admission center.
# 9.Chance of admit : percentage of chance of admission for abroad universities.

# %%
# Defining Problem Statement and Analyzing Basic Metrics.

# Problem Statement:

# Student's chance of Admission for the abroad universities applied by the
# Jambore admission center based on GREScore,TOEFLScore,SOP,LOR,CGPA,Research.

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Reading data from file
df = pd.read_csv("/content/jamboree_admission.csv")

# %%
# Checking the basic structure of dataframe
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# 495         1              0.87
# 496         1              0.96
# 497         1              0.93
# 498         0              0.73
# 499         0              0.84

# %%
# Checking how many rows and columns are there in dataframe
df.shape
# Out:
# (500, 9)

# %%
# Checking the data type of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
# Statistical summary
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# ...

# %%
# Statistical summary including the object data type
df.describe(include = 'all')
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# ...

# %%
# Checking the number of unique students who applied for jambore admission centre
df['Serial No.'].value_counts()
# Out:
# Serial No.
# 1      1
# 330    1
# 343    1
# 342    1
# 341    1
#       ..
# 162    1
# 161    1
# 160    1
# 159    1
# 500    1
# Name: count, Length: 500, dtype: int64

# %%
# Checking the number of unique GREScores of the students
df['GRE Score'].value_counts()
# Out:
# GRE Score
# 312    24
# 324    23
# 316    18
# 321    17
# 322    17
# 327    17
# 311    16
# 320    16
# 314    16
# 317    15
# 325    15
# 315    13
# 308    13
# 323    13
# 326    12
# 319    12
# 313    12
# 304    12
# 300    12
# 318    12
# 305    11
# 301    11
# 310    11
# 307    10
# 329    10
# 299    10
# 298    10
# 331     9
# 340     9
# 328     9
# 309     9
# 334     8
# 332     8
# 330     8
# 306     7
# 302     7
# 297     6
# 296     5
# 295     5
# 336     5
# 303     5
# 338     4
# 335     4
# 333     4
# 339     3
# 337     2
# 290     2
# 294     2
# 293     1
# Name: count, dtype: int64

# %%
# Checking the number of unique TOEFL Scores of the students
df['TOEFL Score'].value_counts()
# Out:
# TOEFL Score
# 110    44
# 105    37
# 104    29
# 107    28
# 106    28
# 112    28
# 103    25
# 100    24
# 102    24
# 99     23
# 101    20
# 111    20
# 108    19
# 113    19
# 109    19
# 114    18
# 116    16
# 115    11
# 118    10
# 98     10
# 119    10
# 120     9
# 117     8
# 97      7
# 96      6
# 95      3
# 93      2
# 94      2
# 92      1
# Name: count, dtype: int64

# %%
# Checking the unique number of University rating given by jambore
df['University Rating'].value_counts()
# Out:
# University Rating
# 3    162
# 2    126
# 4    105
# 5     73
# 1     34
# Name: count, dtype: int64

# %%
# Checking the unique number of sop of the students
df['SOP'].value_counts()
# Out:
# SOP
# 4.0    89
# 3.5    88
# 3.0    80
# 2.5    64
# 4.5    63
# 2.0    43
# 5.0    42
# 1.5    25
# 1.0     6
# Name: count, dtype: int64

# %%
# Checking the unique number of LOR of the students
df['LOR '].value_counts()
# Out:
# LOR
# 3.0    99
# 4.0    94
# 3.5    86
# 4.5    63
# 2.5    50
# 5.0    50
# 2.0    46
# 1.5    11
# 1.0     1
# Name: count, dtype: int64

# %%
# Checking the unique number of CGPA of the students
df['CGPA'].value_counts()
# Out:
# CGPA
# 8.76    9
# 8.00    9
# 8.12    7
# 8.45    7
# 8.54    7
#        ..
# 9.92    1
# 9.35    1
# 8.71    1
# 9.32    1
# 7.69    1
# Name: count, Length: 184, dtype: int64

# %%
# Checking the unique number of research done by the studnets
df['Research'].value_counts()
# Out:
# Research
# 1    280
# 0    220
# Name: count, dtype: int64

# %%
# Checking the chance of admit of the students
df['Chance of Admit '].value_counts()
# Out:
# Chance of Admit
# 0.71    23
# 0.64    19
# 0.73    18
# 0.72    16
# 0.79    16
#         ..
# 0.38     2
# 0.36     2
# 0.43     1
# 0.39     1
# 0.37     1
# Name: count, Length: 61, dtype: int64

# %%
df['Chance of Admit '].nunique()
# Out:
# 61

# %%
# Checking which student has the maximum chance of admit.
df[df['Chance of Admit ']==df['Chance of Admit '].max()]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 24           25        336          119                  5  4.0   3.5  9.80
# 143         144        340          120                  4  4.5   4.0  9.92
# 202         203        340          120                  5  4.5   4.5  9.91
# 203         204        334          120                  5  4.0   5.0  9.87
#
#      Research  Chance of Admit
# 24          1              0.97
# 143         1              0.97
# 202         1              0.97
# 203         1              0.97

# %%
# COMMENT ON THE RANGE OF ATTRIBUTES

# 1. There are 500 rows and 9 columns
# 2. Column names are Serial No., GREScore, TOEFL Score, UniversityRating, SOP,
#.   LOR, CGPA, Research, Chance of Admit.
# 3. Serial No., GREScore, TOEFLScore, UniversityRating, Research are integer data types.
# 4. SOP,LOR,CGPA,Chance of Admit are float data types.
# 5. Statistics of the Chance of Admit column:
#    -Mean               :0.721
#    -Standard deviation :0.14114
#    -Minimum value      :0.34000
#    -Maximum value      :0.97000
# 6. There are 61 unique Chance of admit for joining abroad universities.
# 7. There are only two values present in Research column 0 and 1.We are assuming that 0 represnets no researches done and 1 reprsents research done.
# 8. Maximum chance of admit was the person having was 0.97 of serial no of 23.
# 9. Minimum chance of admit was the person having was 0.34 of serial no of 93,377.
# 10. A total number of 61 unique chance of admit are there.

# %%
# VISUAL ANALYSIS : UNIVARIATE AND BIVARIATE

# FOR CONTINUOUS VARIABLES : DISTPLOT, COUNTPLOT, HISTOGRAM FOR UNIVARIATE ANALYSIS

# %%
# Checking the count of Serial No

sns.countplot(data = df,
              x = 'Serial No.',
              order = df['Serial No.'].value_counts().index
              )
# Out:
# <Axes: xlabel='Serial No.', ylabel='count'>

# %%
# Checking the count of GREscore

sns.countplot(data = df,
              x = 'GRE Score',
              order = df['GRE Score'].value_counts().index
              )
# Out:
# <Axes: xlabel='GRE Score', ylabel='count'>

# %%
# Checking the count of TOEFL Score

sns.countplot(data = df,
              x = 'TOEFL Score',
              order = df['TOEFL Score'].value_counts().index
              )
# Out:
# <Axes: xlabel='TOEFL Score', ylabel='count'>

# %%
# Checking the count of University Rating

sns.countplot(data = df,
              x = 'University Rating',
              order = df['University Rating'].value_counts().index
              )
# Out:
# <Axes: xlabel='University Rating', ylabel='count'>

# %%
# Checking the count of SOP

sns.countplot(data = df,
              x = 'SOP',
              order = df['SOP'].value_counts().index
              )
# Out:
# <Axes: xlabel='SOP', ylabel='count'>

# %%
# Checking the count of LOR

sns.countplot(data = df,
              x = 'LOR ',
              order = df['LOR '].value_counts().index
              )
# Out:
# <Axes: xlabel='LOR ', ylabel='count'>

# %%
# Checking the count of CGPA

sns.countplot(data = df,
              x = 'CGPA',
              order = df['CGPA'].value_counts().index
              )
# Out:
# <Axes: xlabel='CGPA', ylabel='count'>

# %%
# Checking the count of Research

sns.countplot(data = df,
              x = 'Research',
              order = df['Research'].value_counts().index
              )
# Out:
# <Axes: xlabel='Research', ylabel='count'>

# %%
# Checking for null values in tha data set.
null_counts = df.isnull().sum()
null_counts
# As we can observe there are no null values in the data set.
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
# Analyzing if any unique column is there
df.head()
# There is no unique column in the data set
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
# Normalization/feature scaling
# Normalization/feature scaling is the process of converting the data in to the similar range.
#-  It is important while creating the models, because machine gives equal priority to all the columns.
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df1 = pd.DataFrame(scaler.fit_transform(df),columns = df.columns)
df1.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating    SOP   LOR   \
# 0    0.000000       0.94     0.928571               0.75  0.875  0.875
# 1    0.002004       0.68     0.535714               0.75  0.750  0.875
# 2    0.004008       0.52     0.428571               0.50  0.500  0.625
# 3    0.006012       0.64     0.642857               0.50  0.625  0.375
# 4    0.008016       0.48     0.392857               0.25  0.250  0.500
#
#        CGPA  Research  Chance of Admit
# 0  0.913462       1.0          0.920635
# 1  0.663462       1.0          0.666667
# 2  0.384615       1.0          0.603175
# 3  0.599359       1.0          0.730159
# 4  0.451923       0.0          0.492063

# %%
# Splitting the data into dependent and independent variables data.
y = df1['Chance of Admit ']
x = df1.drop(['Chance of Admit ','Serial No.'],axis=1)
x,y
# Out:
# (     GRE Score  TOEFL Score  University Rating    SOP   LOR       CGPA  \
#  0         0.94     0.928571               0.75  0.875  0.875  0.913462
#  1         0.68     0.535714               0.75  0.750  0.875  0.663462
#  2         0.52     0.428571               0.50  0.500  0.625  0.384615
#  3         0.64     0.642857               0.50  0.625  0.375  0.599359
#  4         0.48     0.392857               0.25  0.250  0.500  0.451923
#  ..         ...          ...                ...    ...    ...       ...
#  495       0.84     0.571429               1.00  0.875  0.750  0.711538
#  496       0.94     0.892857               1.00  1.000  1.000  0.983974
#  497       0.80     1.000000               1.00  0.875  1.000  0.884615
#  498       0.44     0.392857               0.75  0.750  1.000  0.522436
#  499       0.74     0.750000               0.75  0.875  0.875  0.717949
#
#       Research
#  0         1.0
#  1         1.0
#  2         1.0
#  3         1.0
#  4         0.0
# ...

# %%
# Splitting the data into train data and test data.
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state = 1)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((350, 7), (150, 7), (350,), (150,))

# %%
# Creating and training the model.
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Using the LASSO regression to train the model
from sklearn.linear_model import Lasso
lasso_model = Lasso()
lasso_model.fit(x_train,y_train)
# Out:
# Lasso()

# %%
# Using the RIDGE regression to train the model
from sklearn.linear_model import Ridge
ridge_model = Ridge()
ridge_model.fit(x_train,y_train)
# Out:
# Ridge()

# %%
# Printing the model coefficients
print(linear_model.coef_)
print(lasso_model.coef_)
print(ridge_model.coef_)
# Out:
# [ 0.13122374  0.16953467  0.06427614 -0.00640967  0.08582427  0.53007408
#   0.04466612]
# [0. 0. 0. 0. 0. 0. 0.]
# [0.16050461 0.18128078 0.07249162 0.01590728 0.0925647  0.41585583
#  0.04947192]

# %%
# Printing the model  intercepts
print(linear_model.intercept_)
print(lasso_model.intercept_)
print(ridge_model.intercept_)
# Out:
# 0.03933168963866973
# 0.6114285714285714
# 0.05821915047730408

# %%
# Accuracy score of the linear model
linear_model.score(x_test,y_test)
# Out:
# 0.8157672116057978

# %%
# Accuracy score of the lasso model
lasso_model.score(x_test,y_test)
# Out:
# -0.005939560521341258

# %%
# Accuracy score of the ridge model
ridge_model.score(x_test,y_test)
# Out:
# 0.806748583486456

# %%
# Predicting the linear model
y_linear_predict = linear_model.predict(x_test)
y_linear_predict
# Out:
# array([0.49651315, 0.58643036, 0.94714376, 0.62136725, 0.75878221,
#        0.52254977, 0.64756052, 0.59424861, 0.71778608, 0.50816342,
#        0.52092128, 0.37087564, 0.71505946, 0.71865653, 0.68985156,
#        0.82537871, 0.45852306, 0.65736754, 0.89249517, 0.53180034,
#        0.45142704, 0.72139899, 0.79192303, 0.43159364, 0.71030427,
#        0.37471801, 0.96767724, 0.48783452, 0.82909873, 0.59559797,
#        0.46608767, 0.75132277, 0.40758573, 0.90313581, 0.27158594,
#        0.76137899, 0.53834664, 0.46585345, 0.50107155, 0.90734393,
#        0.37065472, 0.51870155, 0.69446392, 0.99958149, 0.69530424,
#        0.29150183, 0.50439439, 0.45798039, 0.51904283, 0.4983369 ,
#        0.78382969, 0.91652074, 0.8613519 , 0.46036997, 0.65852171,
#        0.49308307, 0.65383199, 0.4236882 , 0.51899251, 0.58062509,
#        0.16680517, 0.59428888, 0.6474313 , 0.81034582, 1.01024468,
#        0.43157483, 0.63073792, 0.7046961 , 0.93911265, 0.57641653,
# ...

# %%
# Predicting the lasso model
y_lasso_predict = lasso_model.predict(x_test)
y_lasso_predict
# Out:
# array([0.61142857, 0.61142857, 0.61142857, 0.61142857, 0.61142857,
#        0.61142857, 0.61142857, 0.61142857, 0.61142857, 0.61142857,
#        0.61142857, 0.61142857, 0.61142857, 0.61142857, 0.61142857,
#        0.61142857, 0.61142857, 0.61142857, 0.61142857, 0.61142857,
#        0.61142857, 0.61142857, 0.61142857, 0.61142857, 0.61142857,
#        0.61142857, 0.61142857, 0.61142857, 0.61142857, 0.61142857,
#        0.61142857, 0.61142857, 0.61142857, 0.61142857, 0.61142857,
#        0.61142857, 0.61142857, 0.61142857, 0.61142857, 0.61142857,
#        0.61142857, 0.61142857, 0.61142857, 0.61142857, 0.61142857,
#        0.61142857, 0.61142857, 0.61142857, 0.61142857, 0.61142857,
#        0.61142857, 0.61142857, 0.61142857, 0.61142857, 0.61142857,
#        0.61142857, 0.61142857, 0.61142857, 0.61142857, 0.61142857,
#        0.61142857, 0.61142857, 0.61142857, 0.61142857, 0.61142857,
#        0.61142857, 0.61142857, 0.61142857, 0.61142857, 0.61142857,
# ...

# %%
# Predicting the ridge model
y_ridge_predict = ridge_model.predict(x_test)
y_ridge_predict
# Out:
# array([0.48717898, 0.58716622, 0.9326868 , 0.61943436, 0.76219323,
#        0.52057507, 0.642315  , 0.6152124 , 0.71640012, 0.5369725 ,
#        0.5218198 , 0.37450328, 0.71436017, 0.70580667, 0.6878823 ,
#        0.83117871, 0.46120313, 0.64137548, 0.88236708, 0.52149429,
#        0.4573196 , 0.71473107, 0.78819805, 0.45159422, 0.70479105,
#        0.39274307, 0.94563926, 0.48905646, 0.82076569, 0.60008494,
#        0.46394772, 0.74275134, 0.40617067, 0.89584807, 0.2896279 ,
#        0.75177125, 0.52574379, 0.46279573, 0.50025859, 0.89367747,
#        0.36487858, 0.53609584, 0.69474934, 0.98712013, 0.70280932,
#        0.28752874, 0.49339266, 0.47232451, 0.54127587, 0.50707438,
#        0.78817227, 0.91122723, 0.85624609, 0.46744733, 0.63448125,
#        0.4957593 , 0.65972008, 0.42859574, 0.54582729, 0.59267281,
#        0.17203365, 0.59658384, 0.65461798, 0.80899007, 0.99749376,
#        0.4333377 , 0.64178511, 0.71372014, 0.93015322, 0.57523497,
# ...

# %%
# Out:
# 0.010395399941314696

# %%
# Graphical representation of the actual and predicted output.
import matplotlib.pyplot as plt
fig = plt.figure()
plt.scatter(y_test,y_linear_predict)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Mean square error of the linear model
from sklearn.metrics import mean_squared_error
linear_train_mse = mean_squared_error(y_train,linear_model.predict(x_train))
linear_test_mse = mean_squared_error(y_test,linear_model.predict(x_test))
linear_train_mse
linear_test_mse
# Out:
# 0.010395399941314696

# %%
# STATISTICS OF THE MODEL:-

# Linear model coefficient = [ 0.13122374  0.16953467  0.06427614 -0.00640967  0.08582427  0.530074080.04466612]
# Lasso model coefficient =  [0. 0. 0. 0. 0. 0. 0.]
# Ridge model coefficient =  [0.16050461 0.18128078 0.07249162 0.01590728 0.0925647  0.415855830.04947192]

# Linear model intercept = 0.03933168963866973
# Lasso model intercept = 0.6114285714285714
# Ridge model intercept = 0.05821915047730408

# Linear model score = 0.8157672116057978
# Linear model score = -0.005939560521341258
# Linear model score = 0.806748583486456

# mean squared error of the linear model = 0.010395399941314696
