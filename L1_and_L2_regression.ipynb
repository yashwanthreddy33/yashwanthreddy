# %%
 #prepare a LASSO or prepare a L1 and L2 regression models for prediction of house prices
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("/content/housing2.csv")
df
# Out:
#        longitude  latitude  housing_median_age  ...  median_income  median_house_value  ocean_proximity
# 0        -122.23     37.88                41.0  ...         8.3252            452600.0         NEAR BAY
# 1        -122.22     37.86                21.0  ...         8.3014            358500.0         NEAR BAY
# 2        -122.24     37.85                52.0  ...         7.2574            352100.0         NEAR BAY
# 3        -122.25     37.85                52.0  ...         5.6431            341300.0         NEAR BAY
# 4        -122.25     37.85                52.0  ...         3.8462            342200.0         NEAR BAY
# ...          ...       ...                 ...  ...            ...                 ...              ...
# 20635    -121.09     39.48                25.0  ...         1.5603             78100.0           INLAND
# 20636    -121.21     39.49                18.0  ...         2.5568             77100.0           INLAND
# 20637    -121.22     39.43                17.0  ...         1.7000             92300.0           INLAND
# 20638    -121.32     39.43                18.0  ...         1.8672             84700.0           INLAND
# 20639    -121.24     39.37                16.0  ...         2.3886             89400.0           INLAND
#
# [20640 rows x 10 columns]

# %%
df.shape
# Out:
# (20640, 10)

# %%
df["ocean_proximity"] = df.groupby("ocean_proximity")["median_house_value"].transform("mean")
df
# Out:
#        longitude  latitude  housing_median_age  ...  median_income  median_house_value  ocean_proximity
# 0        -122.23     37.88                41.0  ...         8.3252            452600.0    259212.311790
# 1        -122.22     37.86                21.0  ...         8.3014            358500.0    259212.311790
# 2        -122.24     37.85                52.0  ...         7.2574            352100.0    259212.311790
# 3        -122.25     37.85                52.0  ...         5.6431            341300.0    259212.311790
# 4        -122.25     37.85                52.0  ...         3.8462            342200.0    259212.311790
# ...          ...       ...                 ...  ...            ...                 ...              ...
# 20635    -121.09     39.48                25.0  ...         1.5603             78100.0    124805.392001
# 20636    -121.21     39.49                18.0  ...         2.5568             77100.0    124805.392001
# 20637    -121.22     39.43                17.0  ...         1.7000             92300.0    124805.392001
# 20638    -121.32     39.43                18.0  ...         1.8672             84700.0    124805.392001
# 20639    -121.24     39.37                16.0  ...         2.3886             89400.0    124805.392001
#
# [20640 rows x 10 columns]

# %%
#normalisation
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df1 = pd.DataFrame(scaler.fit_transform(df), columns = df.columns)
df1
# Out:
#        longitude  latitude  housing_median_age  ...  median_income  median_house_value  ocean_proximity
# 0       0.211155  0.567481            0.784314  ...       0.539668            0.902266         0.525777
# 1       0.212151  0.565356            0.392157  ...       0.538027            0.708247         0.525777
# 2       0.210159  0.564293            1.000000  ...       0.466028            0.695051         0.525777
# 3       0.209163  0.564293            1.000000  ...       0.354699            0.672783         0.525777
# 4       0.209163  0.564293            1.000000  ...       0.230776            0.674638         0.525777
# ...          ...       ...                 ...  ...            ...                 ...              ...
# 20635   0.324701  0.737513            0.470588  ...       0.073130            0.130105         0.000000
# 20636   0.312749  0.738576            0.333333  ...       0.141853            0.128043         0.000000
# 20637   0.311753  0.732200            0.313725  ...       0.082764            0.159383         0.000000
# 20638   0.301793  0.732200            0.333333  ...       0.094295            0.143713         0.000000
# 20639   0.309761  0.725824            0.294118  ...       0.130253            0.153403         0.000000
#
# [20640 rows x 10 columns]

# %%
df1.fillna(999,inplace = True)
# inplace = true makes the changes parmanent

# %%
y = df1["median_house_value"]
y
# Out:
# 0        0.902266
# 1        0.708247
# 2        0.695051
# 3        0.672783
# 4        0.674638
#            ...
# 20635    0.130105
# 20636    0.128043
# 20637    0.159383
# 20638    0.143713
# 20639    0.153403
# Name: median_house_value, Length: 20640, dtype: float64

# %%
x = df1.drop("median_house_value",axis = 1)
x
# Out:
#        longitude  latitude  housing_median_age  ...  households  median_income  ocean_proximity
# 0       0.211155  0.567481            0.784314  ...    0.020556       0.539668         0.525777
# 1       0.212151  0.565356            0.392157  ...    0.186976       0.538027         0.525777
# 2       0.210159  0.564293            1.000000  ...    0.028943       0.466028         0.525777
# 3       0.209163  0.564293            1.000000  ...    0.035849       0.354699         0.525777
# 4       0.209163  0.564293            1.000000  ...    0.042427       0.230776         0.525777
# ...          ...       ...                 ...  ...         ...            ...              ...
# 20635   0.324701  0.737513            0.470588  ...    0.054103       0.073130         0.000000
# 20636   0.312749  0.738576            0.333333  ...    0.018582       0.141853         0.000000
# 20637   0.311753  0.732200            0.313725  ...    0.071041       0.082764         0.000000
# 20638   0.301793  0.732200            0.333333  ...    0.057227       0.094295         0.000000
# 20639   0.309761  0.725824            0.294118  ...    0.086992       0.130253         0.000000
#
# [20640 rows x 9 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state = 1)
x_train,x_test,y_train,y_test
# Out:
# (       longitude  latitude  housing_median_age  ...  households  median_income  ocean_proximity
#  5748    0.605578  0.172157            0.274510  ...    0.193060       0.166543         0.450952
#  5592    0.606574  0.133900            0.784314  ...    0.074823       0.184687         0.450952
#  2110    0.458167  0.447396            0.941176  ...    0.078277       0.138702         0.000000
#  13901   0.775896  0.161530            0.274510  ...    0.176616       0.140729         0.000000
#  18425   0.250996  0.501594            0.117647  ...    0.111988       0.276093         0.450952
#  ...          ...       ...                 ...  ...         ...            ...              ...
#  10955   0.644422  0.129649            0.313725  ...    0.071534       0.088440         0.450952
#  17289   0.470120  0.199787            0.803922  ...    0.042592       0.555916         0.450952
#  5192    0.606574  0.147715            0.803922  ...    0.048018       0.043634         0.450952
#  12172   0.716135  0.126461            0.176471  ...    0.078277       0.147053         0.000000
#  235     0.214143  0.557917            0.666667  ...    0.063970       0.124391         0.525777
#
#  [14448 rows x 9 columns],
#         longitude  latitude  housing_median_age  ...  households  median_income  ocean_proximity
#  4712    0.596614  0.161530            0.745098  ...    0.102450       0.189659         0.450952
#  2151    0.455179  0.450584            0.705882  ...    0.071863       0.101964         0.000000
#  15927   0.192231  0.551541            0.882353  ...    0.066601       0.242293         0.525777
#  82      0.206175  0.560043            1.000000  ...    0.014142       0.070406         0.525777
#  8161    0.619522  0.136026            0.705882  ...    0.046374       0.322727         0.450952
#  ...          ...       ...                 ...  ...         ...            ...              ...
#  11387   0.634462  0.117960            0.333333  ...    0.029436       0.256272         0.450952
#  2523    0.220120  0.755579            0.627451  ...    0.010853       0.216756         0.000000
#  18897   0.209163  0.592986            0.901961  ...    0.046867       0.143901         0.525777
#  18878   0.210159  0.587673            0.235294  ...    0.177602       0.145508         0.525777
#  4287    0.602590  0.165781            0.549020  ...    0.192896       0.083337         0.450952
#
#  [6192 rows x 9 columns],
#  5748     0.461237
#  5592     0.321856
#  2110     0.083301
#  13901    0.112579
#  18425    0.408454
#             ...
#  10955    0.392372
#  17289    1.000000
#  5192     0.185156
#  12172    0.259176
#  235      0.228867
#  Name: median_house_value, Length: 14448, dtype: float64,
#  4712     0.701030
#  2151     0.114847
#  15927    0.442062
#  82       0.201032
#  8161     0.433815
#             ...
#  11387    0.404743
#  2523     0.149486
#  18897    0.195465
#  18878    0.304125
#  4287     0.312784
#  Name: median_house_value, Length: 6192, dtype: float64)

# %%
linear_model = LinearRegression()
lasso_model = Lasso(alpha = 0.1)
ridge_model = Ridge(alpha = 0.1)
# alpha is the regularisation parameter which we are adding as an error term to our model
# We are not taking the errors added in the feature

# %%
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lasso_model.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.1)

# %%
ridge_model.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.1)

# %%
print(linear_model.coef_)
print(lasso_model.coef_)
print(ridge_model.coef_)
# Out:
# [-5.21369632e-01 -4.80885402e-01  1.05448058e-01 -9.95155295e-02
#   9.05811317e-07 -2.96900236e+00  1.71684723e+00  1.14140894e+00
#   1.78608947e-01]
# [-0. -0.  0.  0.  0. -0.  0.  0.  0.]
# [-5.19071574e-01 -4.77794156e-01  1.05589015e-01 -8.48795182e-02
#   8.27450951e-07 -2.83592891e+00  1.64191665e+00  1.13973254e+00
#   1.80420220e-01]

# %%
print(linear_model.intercept_)
print(lasso_model.intercept_)
print(ridge_model.intercept_)
# Out:
# 0.40752917375286374
# 0.3972234099154518
# 0.4050122758456162

# %%
linear_model.score(x_test,y_test)
# Out:
# 0.6363169885864803

# %%
lasso_model.score(x_test,y_test)
# Out:
# -0.0005372966032284321

# %%
ridge_model.score(x_test,y_test)
# Out:
# 0.636010311671446

# %%
linear_train_mse = mean_squared_error(y_train,linear_model.predict(x_train))
linear_test_mse = mean_squared_error(y_test,linear_model.predict(x_test))
print(linear_train_mse)
print(linear_test_mse)
# Out:
# 0.02023851649428413
# 0.0203262390236933
